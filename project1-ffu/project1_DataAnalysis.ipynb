# %%
#AML Project 1, FFU
import pandas as pd
import numpy as np
import os.path

#absolute path data
path = '~/Documents/GitHub/aml2020/task1'

#Load in the training data
fname = 'X_train.csv'
fpath = os.path.join(path,fname)
df_x = pd.read_csv(fpath)

fname = 'y_train.csv'
fpath = os.path.join(path,fname)
df_y = pd.read_csv(fpath)

# %%
#check data type and summary statisitcs
df_x.dtypes
# Out:
# id      float64
# x0      float64
# x1      float64
# x2      float64
# x3      float64
#          ...
# x827    float64
# x828    float64
# x829    float64
# x830    float64
# x831    float64
# Length: 833, dtype: object

# %%
#check summary stats
df_x.describe(include='all')
# Out:
#                 id           x0             x1            x2           x3  \
# count  1212.000000  1118.000000    1114.000000   1117.000000  1106.000000
# mean    605.500000    10.026057  832442.859290  20585.524887  1048.958235
# std     350.018571     0.968347       0.028258      0.029051    28.430733
# min       0.000000     6.672068  832442.808579  20585.473809  1000.063783
# 25%     302.750000     9.381273  832442.835941  20585.501013  1024.969967
# 50%     605.500000    10.000079  832442.860041  20585.524817  1047.985497
# 75%     908.250000    10.664998  832442.882951  20585.550525  1073.180317
# max    1211.000000    12.956099  832442.908334  20585.573514  1099.977638
#
#                  x4           x5             x6            x7            x8  \
# count  1.117000e+03  1128.000000    1105.000000   1127.000000  1.116000e+03
# mean   1.000291e+06    10.085010  597900.429955  10389.657239  9.998422e+05
# std    9.740891e+04     0.968026       0.028128   1655.843472  1.022441e+05
# min    6.800215e+05     6.984052  597900.381003   3644.074892  6.095730e+05
# 25%    9.360882e+05     9.470582  597900.406110   9339.537887  9.322937e+05
# 50%    1.000557e+06    10.089601  597900.429787  10295.013382  1.001261e+06
# 75%    1.064617e+06    10.752707  597900.452983  11304.073469  1.068359e+06
# max    1.331630e+06    12.747734  597900.480810  17347.531573  1.284804e+06
#
#        ...          x822         x823          x824         x825         x826  \
# count  ...  1.134000e+03  1125.000000   1098.000000  1121.000000  1120.000000
# mean   ...  1.049674e+06  -876.044006  13492.600186    10.554762    10.057767
# std    ...  2.839579e+04   164.585576   2519.835006     0.283844     0.982656
# min    ...  1.000105e+06 -1597.766964   2536.030655    10.010366     6.841039
# 25%    ...  1.025054e+06  -975.398714  11947.954006    10.321039     9.379001
# 50%    ...  1.049296e+06  -875.508235  13352.186179    10.554260    10.114370
# 75%    ...  1.074354e+06  -773.174562  14893.726023    10.792195    10.745370
# max    ...  1.099771e+06  -281.030205  24815.260375    11.091050    13.530204
#
#               x827         x828          x829           x830           x831
# count  1109.000000  1115.000000  1.112000e+03    1124.000000    1091.000000
# mean   1066.141107    10.008269  1.050199e+06   99798.480171  104903.905758
# std     226.606986     1.018930  2.814210e+04    9576.128720    2768.405350
# min     496.007706     6.466963  1.000002e+06   73207.994891  100012.896777
# 25%     899.067501     9.325229  1.027575e+06   93416.252400  102596.190683
# 50%    1049.027077    10.005684  1.050262e+06   99802.127899  104846.235709
# 75%    1215.057985    10.658120  1.073831e+06  106400.748441  107098.669350
# max    2122.032859    13.163113  1.099918e+06  130694.436443  109984.169649
#
# [8 rows x 833 columns]

# %%
#check for missing values
missing_data = df_x.isnull()
missing_data.head(5)
# Out:
#       id     x0     x1     x2     x3     x4     x5     x6     x7     x8  ...  \
# 0  False  False  False  False  False  False  False  False   True  False  ...
# 1  False  False  False   True  False  False  False  False  False  False  ...
# 2  False  False  False  False  False  False  False  False  False  False  ...
# 3  False  False   True   True  False  False  False  False  False  False  ...
# 4  False  False  False  False   True  False  False  False  False  False  ...
#
#     x822   x823   x824   x825   x826   x827   x828   x829   x830   x831
# 0  False  False  False  False  False  False  False  False  False  False
# 1  False  False  False  False  False  False  False  False  False  False
# 2  False  False  False  False  False  False  False  False  False  False
# 3  False  False  False  False  False  False  False  False   True  False
# 4  False  False  False   True   True  False  False  False  False  False
#
# [5 rows x 833 columns]

# %%
#count missing values
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# 493
# False    1124
# True       88
# Name: x493, dtype: int64
#
# x494
# False    1110
# True      102
# Name: x494, dtype: int64
#
# x495
# False    1101
# True      111
# Name: x495, dtype: int64
#
# x496
# False    1111
# True      101
# Name: x496, dtype: int64
#
# x497
# False    1107
# True      105
# Name: x497, dtype: int64
#
# x498
# False    1107
# True      105
# Name: x498, dtype: int64
#
# x499
# False    1105
# True      107
# Name: x499, dtype: int64
#
# x500
# False    1125
# True       87
# Name: x500, dtype: int64
#
# x501
# False    1127
# True       85
# Name: x501, dtype: int64
#
# x502
# False    1103
# True      109
# Name: x502, dtype: int64
#
# x503
# False    1129
# True       83
# Name: x503, dtype: int64
#
# x504
# False    1117
# True       95
# Name: x504, dtype: int64
#
# x505
# False    1129
# True       83
# Name: x505, dtype: int64
#
# x506
# False    1133
# True       79
# Name: x506, dtype: int64
#
# x507
# False    1119
# True       93
# Name: x507, dtype: int64
#
# x508
# False    1116
# True       96
# Name: x508, dtype: int64
#
# x509
# False    1126
# True       86
# Name: x509, dtype: int64
#
# x510
# False    1118
# True       94
# Name: x510, dtype: int64
#
# x511
# False    1126
# True       86
# Name: x511, dtype: int64
#
# x512
# False    1130
# True       82
# Name: x512, dtype: int64
#
# x513
# False    1127
# True       85
# Name: x513, dtype: int64
#
# x514
# False    1125
# True       87
# Name: x514, dtype: int64
#
# x515
# False    1111
# True      101
# Name: x515, dtype: int64
#
# x516
# False    1111
# True      101
# Name: x516, dtype: int64
#
# x517
# False    1115
# True       97
# Name: x517, dtype: int64
#
# x518
# False    1103
# True      109
# Name: x518, dtype: int64
#
# x519
# False    1133
# True       79
# Name: x519, dtype: int64
#
# x520
# False    1112
# True      100
# Name: x520, dtype: int64
#
# x521
# False    1119
# True       93
# Name: x521, dtype: int64
#
# x522
# False    1147
# True       65
# Name: x522, dtype: int64
#
# x523
# False    1125
# True       87
# Name: x523, dtype: int64
#
# x524
# False    1127
# True       85
# Name: x524, dtype: int64
#
# x525
# False    1109
# True      103
# Name: x525, dtype: int64
#
# x526
# False    1113
# True       99
# Name: x526, dtype: int64
#
# x527
# False    1117
# True       95
# Name: x527, dtype: int64
#
# x528
# False    1131
# True       81
# Name: x528, dtype: int64
#
# x529
# False    1127
# True       85
# Name: x529, dtype: int64
#
# x530
# False    1134
# True       78
# Name: x530, dtype: int64
#
# x531
# False    1114
# True       98
# Name: x531, dtype: int64
#
# x532
# False    1110
# True      102
# Name: x532, dtype: int64
#
# x533
# False    1118
# True       94
# Name: x533, dtype: int64
#
# x534
# False    1115
# True       97
# Name: x534, dtype: int64
#
# x535
# False    1125
# True       87
# Name: x535, dtype: int64
#
# x536
# False    1132
# True       80
# Name: x536, dtype: int64
#
# x537
# False    1132
# True       80
# Name: x537, dtype: int64
#
# x538
# False    1115
# True       97
# Name: x538, dtype: int64
#
# x539
# False    1118
# True       94
# Name: x539, dtype: int64
#
# x540
# False    1125
# True       87
# Name: x540, dtype: int64
#
# x541
# False    1113
# True       99
# Name: x541, dtype: int64
#
# x542
# False    1129
# True       83
# Name: x542, dtype: int64
#
# x543
# False    1111
# True      101
# Name: x543, dtype: int64
#
# x544
# False    1110
# True      102
# Name: x544, dtype: int64
#
# x545
# False    1126
# True       86
# Name: x545, dtype: int64
#
# x546
# False    1088
# True      124
# Name: x546, dtype: int64
#
# x547
# False    1132
# True       80
# Name: x547, dtype: int64
#
# x548
# False    1124
# True       88
# Name: x548, dtype: int64
#
# x549
# False    1124
# True       88
# Name: x549, dtype: int64
#
# x550
# False    1122
# True       90
# Name: x550, dtype: int64
#
# x551
# False    1125
# True       87
# Name: x551, dtype: int64
#
# x552
# False    1120
# True       92
# Name: x552, dtype: int64
#
# x553
# False    1133
# True       79
# Name: x553, dtype: int64
#
# x554
# False    1124
# True       88
# Name: x554, dtype: int64
#
# x555
# False    1121
# True       91
# Name: x555, dtype: int64
#
# x556
# False    1108
# True      104
# Name: x556, dtype: int64
#
# x557
# False    1118
# True       94
# Name: x557, dtype: int64
#
# x558
# False    1115
# True       97
# Name: x558, dtype: int64
#
# x559
# False    1110
# True      102
# Name: x559, dtype: int64
#
# x560
# False    1128
# True       84
# Name: x560, dtype: int64
#
# x561
# False    1115
# True       97
# Name: x561, dtype: int64
#
# x562
# False    1119
# True       93
# Name: x562, dtype: int64
#
# x563
# False    1116
# True       96
# Name: x563, dtype: int64
#
# x564
# False    1116
# True       96
# Name: x564, dtype: int64
#
# x565
# False    1110
# True      102
# Name: x565, dtype: int64
#
# x566
# False    1126
# True       86
# Name: x566, dtype: int64
#
# x567
# False    1122
# True       90
# Name: x567, dtype: int64
#
# x568
# False    1103
# True      109
# Name: x568, dtype: int64
#
# x569
# False    1131
# True       81
# Name: x569, dtype: int64
#
# x570
# False    1112
# True      100
# Name: x570, dtype: int64
#
# x571
# False    1123
# True       89
# Name: x571, dtype: int64
#
# x572
# False    1116
# True       96
# Name: x572, dtype: int64
#
# x573
# False    1130
# True       82
# Name: x573, dtype: int64
#
# x574
# False    1130
# True       82
# Name: x574, dtype: int64
#
# x575
# False    1126
# True       86
# Name: x575, dtype: int64
#
# x576
# False    1121
# True       91
# Name: x576, dtype: int64
#
# x577
# False    1102
# True      110
# Name: x577, dtype: int64
#
# x578
# False    1104
# True      108
# Name: x578, dtype: int64
#
# x579
# False    1126
# True       86
# Name: x579, dtype: int64
#
# x580
# False    1112
# True      100
# Name: x580, dtype: int64
#
# x581
# False    1120
# True       92
# Name: x581, dtype: int64
#
# x582
# False    1133
# True       79
# Name: x582, dtype: int64
#
# x583
# False    1126
# True       86
# Name: x583, dtype: int64
#
# x584
# False    1134
# True       78
# Name: x584, dtype: int64
#
# x585
# False    1130
# True       82
# Name: x585, dtype: int64
#
# x586
# False    1110
# True      102
# Name: x586, dtype: int64
#
# x587
# False    1119
# True       93
# Name: x587, dtype: int64
#
# x588
# False    1122
# True       90
# Name: x588, dtype: int64
#
# x589
# False    1130
# True       82
# Name: x589, dtype: int64
#
# x590
# False    1132
# True       80
# Name: x590, dtype: int64
#
# x591
# False    1112
# True      100
# Name: x591, dtype: int64
#
# x592
# False    1113
# True       99
# Name: x592, dtype: int64
#
# x593
# False    1118
# True       94
# Name: x593, dtype: int64
#
# x594
# False    1108
# True      104
# Name: x594, dtype: int64
#
# x595
# False    1123
# True       89
# Name: x595, dtype: int64
#
# x596
# False    1141
# True       71
# Name: x596, dtype: int64
#
# x597
# False    1103
# True      109
# Name: x597, dtype: int64
#
# x598
# False    1126
# True       86
# Name: x598, dtype: int64
#
# x599
# False    1131
# True       81
# Name: x599, dtype: int64
#
# x600
# False    1112
# True      100
# Name: x600, dtype: int64
#
# x601
# False    1118
# True       94
# Name: x601, dtype: int64
#
# x602
# False    1117
# True       95
# Name: x602, dtype: int64
#
# x603
# False    1107
# True      105
# Name: x603, dtype: int64
#
# x604
# False    1103
# True      109
# Name: x604, dtype: int64
#
# x605
# False    1116
# True       96
# Name: x605, dtype: int64
#
# x606
# False    1109
# True      103
# Name: x606, dtype: int64
#
# x607
# False    1115
# True       97
# Name: x607, dtype: int64
#
# x608
# False    1118
# True       94
# Name: x608, dtype: int64
#
# x609
# False    1121
# True       91
# Name: x609, dtype: int64
#
# x610
# False    1107
# True      105
# Name: x610, dtype: int64
#
# x611
# False    1132
# True       80
# Name: x611, dtype: int64
#
# x612
# False    1125
# True       87
# Name: x612, dtype: int64
#
# x613
# False    1112
# True      100
# Name: x613, dtype: int64
#
# x614
# False    1131
# True       81
# Name: x614, dtype: int64
#
# x615
# False    1109
# True      103
# Name: x615, dtype: int64
#
# x616
# False    1124
# True       88
# Name: x616, dtype: int64
#
# x617
# False    1100
# True      112
# Name: x617, dtype: int64
#
# x618
# False    1118
# True       94
# Name: x618, dtype: int64
#
# x619
# False    1112
# True      100
# Name: x619, dtype: int64
#
# x620
# False    1112
# True      100
# Name: x620, dtype: int64
#
# x621
# False    1120
# True       92
# Name: x621, dtype: int64
#
# x622
# False    1113
# True       99
# Name: x622, dtype: int64
#
# x623
# False    1115
# True       97
# Name: x623, dtype: int64
#
# x624
# False    1107
# True      105
# Name: x624, dtype: int64
#
# x625
# False    1111
# True      101
# Name: x625, dtype: int64
#
# x626
# False    1107
# True      105
# Name: x626, dtype: int64
#
# x627
# False    1121
# True       91
# Name: x627, dtype: int64
#
# x628
# False    1124
# True       88
# Name: x628, dtype: int64
#
# x629
# False    1112
# True      100
# Name: x629, dtype: int64
#
# x630
# False    1132
# True       80
# Name: x630, dtype: int64
#
# x631
# False    1109
# True      103
# Name: x631, dtype: int64
#
# x632
# False    1120
# True       92
# Name: x632, dtype: int64
#
# x633
# False    1112
# True      100
# Name: x633, dtype: int64
#
# x634
# False    1116
# True       96
# Name: x634, dtype: int64
#
# x635
# False    1120
# True       92
# Name: x635, dtype: int64
#
# x636
# False    1126
# True       86
# Name: x636, dtype: int64
#
# x637
# False    1118
# True       94
# Name: x637, dtype: int64
#
# x638
# False    1145
# True       67
# Name: x638, dtype: int64
#
# x639
# False    1114
# True       98
# Name: x639, dtype: int64
#
# x640
# False    1116
# True       96
# Name: x640, dtype: int64
#
# x641
# False    1122
# True       90
# Name: x641, dtype: int64
#
# x642
# False    1108
# True      104
# Name: x642, dtype: int64
#
# x643
# False    1129
# True       83
# Name: x643, dtype: int64
#
# x644
# False    1128
# True       84
# Name: x644, dtype: int64
#
# x645
# False    1122
# True       90
# Name: x645, dtype: int64
#
# x646
# False    1105
# True      107
# Name: x646, dtype: int64
#
# x647
# False    1129
# True       83
# Name: x647, dtype: int64
#
# x648
# False    1102
# True      110
# Name: x648, dtype: int64
#
# x649
# False    1131
# True       81
# Name: x649, dtype: int64
#
# x650
# False    1117
# True       95
# Name: x650, dtype: int64
#
# x651
# False    1112
# True      100
# Name: x651, dtype: int64
#
# x652
# False    1115
# True       97
# Name: x652, dtype: int64
#
# x653
# False    1113
# True       99
# Name: x653, dtype: int64
#
# x654
# False    1115
# True       97
# Name: x654, dtype: int64
#
# x655
# False    1108
# True      104
# Name: x655, dtype: int64
#
# x656
# False    1107
# True      105
# Name: x656, dtype: int64
#
# x657
# False    1126
# True       86
# Name: x657, dtype: int64
#
# x658
# False    1114
# True       98
# Name: x658, dtype: int64
#
# x659
# False    1135
# True       77
# Name: x659, dtype: int64
#
# x660
# False    1117
# True       95
# Name: x660, dtype: int64
#
# x661
# False    1123
# True       89
# Name: x661, dtype: int64
#
# x662
# False    1102
# True      110
# Name: x662, dtype: int64
#
# x663
# False    1111
# True      101
# Name: x663, dtype: int64
#
# x664
# False    1127
# True       85
# Name: x664, dtype: int64
#
# x665
# False    1117
# True       95
# Name: x665, dtype: int64
#
# x666
# False    1121
# True       91
# Name: x666, dtype: int64
#
# x667
# False    1113
# True       99
# Name: x667, dtype: int64
#
# x668
# False    1116
# True       96
# Name: x668, dtype: int64
#
# x669
# False    1090
# True      122
# Name: x669, dtype: int64
#
# x670
# False    1120
# True       92
# Name: x670, dtype: int64
#
# x671
# False    1115
# True       97
# Name: x671, dtype: int64
#
# x672
# False    1112
# True      100
# Name: x672, dtype: int64
#
# x673
# False    1143
# True       69
# Name: x673, dtype: int64
#
# x674
# False    1114
# True       98
# Name: x674, dtype: int64
#
# x675
# False    1129
# True       83
# Name: x675, dtype: int64
#
# x676
# False    1105
# True      107
# Name: x676, dtype: int64
#
# x677
# False    1129
# True       83
# Name: x677, dtype: int64
#
# x678
# False    1112
# True      100
# Name: x678, dtype: int64
#
# x679
# False    1128
# True       84
# Name: x679, dtype: int64
#
# x680
# False    1124
# True       88
# Name: x680, dtype: int64
#
# x681
# False    1113
# True       99
# Name: x681, dtype: int64
#
# x682
# False    1125
# True       87
# Name: x682, dtype: int64
#
# x683
# False    1112
# True      100
# Name: x683, dtype: int64
#
# x684
# False    1112
# True      100
# Name: x684, dtype: int64
#
# x685
# False    1124
# True       88
# Name: x685, dtype: int64
#
# x686
# False    1129
# True       83
# Name: x686, dtype: int64
#
# x687
# False    1117
# True       95
# Name: x687, dtype: int64
#
# x688
# False    1135
# True       77
# Name: x688, dtype: int64
#
# x689
# False    1110
# True      102
# Name: x689, dtype: int64
#
# x690
# False    1113
# True       99
# Name: x690, dtype: int64
#
# x691
# False    1141
# True       71
# Name: x691, dtype: int64
#
# x692
# False    1127
# True       85
# Name: x692, dtype: int64
#
# x693
# False    1117
# True       95
# Name: x693, dtype: int64
#
# x694
# False    1145
# True       67
# Name: x694, dtype: int64
#
# x695
# False    1116
# True       96
# Name: x695, dtype: int64
#
# x696
# False    1113
# True       99
# Name: x696, dtype: int64
#
# x697
# False    1115
# True       97
# Name: x697, dtype: int64
#
# x698
# False    1117
# True       95
# Name: x698, dtype: int64
#
# x699
# False    1118
# True       94
# Name: x699, dtype: int64
#
# x700
# False    1130
# True       82
# Name: x700, dtype: int64
#
# x701
# False    1088
# True      124
# Name: x701, dtype: int64
#
# x702
# False    1104
# True      108
# Name: x702, dtype: int64
#
# x703
# False    1123
# True       89
# Name: x703, dtype: int64
#
# x704
# False    1126
# True       86
# Name: x704, dtype: int64
#
# x705
# False    1121
# True       91
# Name: x705, dtype: int64
#
# x706
# False    1112
# True      100
# Name: x706, dtype: int64
#
# x707
# False    1127
# True       85
# Name: x707, dtype: int64
#
# x708
# False    1134
# True       78
# Name: x708, dtype: int64
#
# x709
# False    1112
# True      100
# Name: x709, dtype: int64
#
# x710
# False    1116
# True       96
# Name: x710, dtype: int64
#
# x711
# False    1118
# True       94
# Name: x711, dtype: int64
#
# x712
# False    1141
# True       71
# Name: x712, dtype: int64
#
# x713
# False    1123
# True       89
# Name: x713, dtype: int64
#
# x714
# False    1109
# True      103
# Name: x714, dtype: int64
#
# x715
# False    1133
# True       79
# Name: x715, dtype: int64
#
# x716
# False    1124
# True       88
# Name: x716, dtype: int64
#
# x717
# False    1130
# True       82
# Name: x717, dtype: int64
#
# x718
# False    1141
# True       71
# Name: x718, dtype: int64
#
# x719
# False    1117
# True       95
# Name: x719, dtype: int64
#
# x720
# False    1118
# True       94
# Name: x720, dtype: int64
#
# x721
# False    1118
# True       94
# Name: x721, dtype: int64
#
# x722
# False    1105
# True      107
# Name: x722, dtype: int64
#
# x723
# False    1119
# True       93
# Name: x723, dtype: int64
#
# x724
# False    1119
# True       93
# Name: x724, dtype: int64
#
# x725
# False    1122
# True       90
# Name: x725, dtype: int64
#
# x726
# False    1129
# True       83
# Name: x726, dtype: int64
#
# x727
# False    1118
# True       94
# Name: x727, dtype: int64
#
# x728
# False    1123
# True       89
# Name: x728, dtype: int64
#
# x729
# False    1106
# True      106
# Name: x729, dtype: int64
#
# x730
# False    1124
# True       88
# Name: x730, dtype: int64
#
# x731
# False    1123
# True       89
# Name: x731, dtype: int64
#
# x732
# False    1129
# True       83
# Name: x732, dtype: int64
#
# x733
# False    1133
# True       79
# Name: x733, dtype: int64
#
# x734
# False    1111
# True      101
# Name: x734, dtype: int64
#
# x735
# False    1120
# True       92
# Name: x735, dtype: int64
#
# x736
# False    1119
# True       93
# Name: x736, dtype: int64
#
# x737
# False    1122
# True       90
# Name: x737, dtype: int64
#
# x738
# False    1120
# True       92
# Name: x738, dtype: int64
#
# x739
# False    1120
# True       92
# Name: x739, dtype: int64
#
# x740
# False    1122
# True       90
# Name: x740, dtype: int64
#
# x741
# False    1129
# True       83
# Name: x741, dtype: int64
#
# x742
# False    1109
# True      103
# Name: x742, dtype: int64
#
# x743
# False    1113
# True       99
# Name: x743, dtype: int64
#
# x744
# False    1122
# True       90
# Name: x744, dtype: int64
#
# x745
# False    1127
# True       85
# Name: x745, dtype: int64
#
# x746
# False    1124
# True       88
# Name: x746, dtype: int64
#
# x747
# False    1115
# True       97
# Name: x747, dtype: int64
#
# x748
# False    1125
# True       87
# Name: x748, dtype: int64
#
# x749
# False    1124
# True       88
# Name: x749, dtype: int64
#
# x750
# False    1107
# True      105
# Name: x750, dtype: int64
#
# x751
# False    1115
# True       97
# Name: x751, dtype: int64
#
# x752
# False    1111
# True      101
# Name: x752, dtype: int64
#
# x753
# False    1120
# True       92
# Name: x753, dtype: int64
#
# x754
# False    1124
# True       88
# Name: x754, dtype: int64
#
# x755
# False    1112
# True      100
# Name: x755, dtype: int64
#
# x756
# False    1130
# True       82
# Name: x756, dtype: int64
#
# x757
# False    1138
# True       74
# Name: x757, dtype: int64
#
# x758
# False    1127
# True       85
# Name: x758, dtype: int64
#
# x759
# False    1121
# True       91
# Name: x759, dtype: int64
#
# x760
# False    1118
# True       94
# Name: x760, dtype: int64
#
# x761
# False    1140
# True       72
# Name: x761, dtype: int64
#
# x762
# False    1111
# True      101
# Name: x762, dtype: int64
#
# x763
# False    1128
# True       84
# Name: x763, dtype: int64
#
# x764
# False    1103
# True      109
# Name: x764, dtype: int64
#
# x765
# False    1118
# True       94
# Name: x765, dtype: int64
#
# x766
# False    1114
# True       98
# Name: x766, dtype: int64
#
# x767
# False    1134
# True       78
# Name: x767, dtype: int64
#
# x768
# False    1113
# True       99
# Name: x768, dtype: int64
#
# x769
# False    1111
# True      101
# Name: x769, dtype: int64
#
# x770
# False    1124
# True       88
# Name: x770, dtype: int64
#
# x771
# False    1111
# True      101
# Name: x771, dtype: int64
#
# x772
# False    1112
# True      100
# Name: x772, dtype: int64
#
# x773
# False    1140
# True       72
# Name: x773, dtype: int64
#
# x774
# False    1102
# True      110
# Name: x774, dtype: int64
#
# x775
# False    1119
# True       93
# Name: x775, dtype: int64
#
# x776
# False    1100
# True      112
# Name: x776, dtype: int64
#
# x777
# False    1114
# True       98
# Name: x777, dtype: int64
#
# x778
# False    1117
# True       95
# Name: x778, dtype: int64
#
# x779
# False    1117
# True       95
# Name: x779, dtype: int64
#
# x780
# False    1122
# True       90
# Name: x780, dtype: int64
#
# x781
# False    1112
# True      100
# Name: x781, dtype: int64
#
# x782
# False    1128
# True       84
# Name: x782, dtype: int64
#
# x783
# False    1126
# True       86
# Name: x783, dtype: int64
#
# x784
# False    1120
# True       92
# Name: x784, dtype: int64
#
# x785
# False    1122
# True       90
# Name: x785, dtype: int64
#
# x786
# False    1127
# True       85
# Name: x786, dtype: int64
#
# x787
# False    1128
# True       84
# Name: x787, dtype: int64
#
# x788
# False    1101
# True      111
# Name: x788, dtype: int64
#
# x789
# False    1132
# True       80
# Name: x789, dtype: int64
#
# x790
# False    1114
# True       98
# Name: x790, dtype: int64
#
# x791
# False    1117
# True       95
# Name: x791, dtype: int64
#
# x792
# False    1130
# True       82
# Name: x792, dtype: int64
#
# x793
# False    1110
# True      102
# Name: x793, dtype: int64
#
# x794
# False    1108
# True      104
# Name: x794, dtype: int64
#
# x795
# False    1109
# True      103
# Name: x795, dtype: int64
#
# x796
# False    1132
# True       80
# Name: x796, dtype: int64
#
# x797
# False    1142
# True       70
# Name: x797, dtype: int64
#
# x798
# False    1131
# True       81
# Name: x798, dtype: int64
#
# x799
# False    1122
# True       90
# Name: x799, dtype: int64
#
# x800
# False    1128
# True       84
# Name: x800, dtype: int64
#
# x801
# False    1112
# True      100
# Name: x801, dtype: int64
#
# x802
# False    1120
# True       92
# Name: x802, dtype: int64
#
# x803
# False    1128
# True       84
# Name: x803, dtype: int64
#
# x804
# False    1105
# True      107
# Name: x804, dtype: int64
#
# x805
# False    1113
# True       99
# Name: x805, dtype: int64
#
# x806
# False    1135
# True       77
# Name: x806, dtype: int64
#
# x807
# False    1132
# True       80
# Name: x807, dtype: int64
#
# x808
# False    1126
# True       86
# Name: x808, dtype: int64
#
# x809
# False    1112
# True      100
# Name: x809, dtype: int64
#
# x810
# False    1102
# True      110
# Name: x810, dtype: int64
#
# x811
# False    1124
# True       88
# Name: x811, dtype: int64
#
# x812
# False    1130
# True       82
# Name: x812, dtype: int64
#
# x813
# False    1118
# True       94
# Name: x813, dtype: int64
#
# x814
# False    1114
# True       98
# Name: x814, dtype: int64
#
# x815
# False    1128
# True       84
# Name: x815, dtype: int64
#
# x816
# False    1119
# True       93
# Name: x816, dtype: int64
#
# x817
# False    1123
# True       89
# Name: x817, dtype: int64
#
# x818
# False    1116
# True       96
# Name: x818, dtype: int64
#
# x819
# False    1135
# True       77
# Name: x819, dtype: int64
#
# x820
# False    1127
# True       85
# Name: x820, dtype: int64
#
# x821
# False    1129
# True       83
# Name: x821, dtype: int64
#
# x822
# False    1134
# True       78
# Name: x822, dtype: int64
#
# x823
# False    1125
# True       87
# Name: x823, dtype: int64
#
# x824
# False    1098
# True      114
# Name: x824, dtype: int64
#
# x825
# False    1121
# True       91
# Name: x825, dtype: int64
#
# x826
# False    1120
# True       92
# Name: x826, dtype: int64
#
# x827
# False    1109
# True      103
# Name: x827, dtype: int64
#
# x828
# False    1115
# True       97
# Name: x828, dtype: int64
#
# x829
# False    1112
# True      100
# Name: x829, dtype: int64
#
# x830
# False    1124
# True       88
# Name: x830, dtype: int64
#
# x831
# False    1091
# True      121
# Name: x831, dtype: int64

# %%
#check for missing values in y
missing_data = df_y.isnull()
missing_data.head(5)
# Out:
#       id      y
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False
# 4  False  False

# %%
#count missing values in y
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# id
# False    1212
# Name: id, dtype: int64
#
# y
# False    1212
# Name: y, dtype: int64

# %%
#identify columns which contains constant values and some noise.
#use the coefficient of variation CV as metric (CV = sigma/mean).
#drop columns in which CV < 1e3 (try different values of CV)
#I have checked out that cv_min < 1e-2 has no impact. However, choosing cv_min < 1e-1 removes additionally ~600 columns. To be checked
cv_min = 1e-1
dropped_cols_mean = [] #zero mean
dropped_cols_cv = [] #CV
n = 0
n_tot = len(df_x.columns)
for column in df_x:
    mean = df_x[column].astype("float").mean()
    if mean == 0:
        print("mean = 0: dropping column", column)
        dropped_cols_mean.append(column)
        n = n+1
    else: 
        cv = df_x[column].astype("float").std()/mean
        if cv < cv_min:
            print("cv < ", cv_min,": dropping column", column)
            dropped_cols_cv.append(column)
            n = n+1
#print("dropped columns %d / %d",n,n_tot)
print(n,n_tot)
# Out:
# ng column x3
# cv <  0.1 : dropping column x4
# cv <  0.1 : dropping column x5
# cv <  0.1 : dropping column x6
# cv <  0.1 : dropping column x9
# cv <  0.1 : dropping column x11
# cv <  0.1 : dropping column x13
# cv <  0.1 : dropping column x14
# cv <  0.1 : dropping column x15
# cv <  0.1 : dropping column x16
# cv <  0.1 : dropping column x17
# cv <  0.1 : dropping column x18
# cv <  0.1 : dropping column x19
# cv <  0.1 : dropping column x20
# cv <  0.1 : dropping column x21
# cv <  0.1 : dropping column x23
# cv <  0.1 : dropping column x24
# cv <  0.1 : dropping column x26
# cv <  0.1 : dropping column x27
# cv <  0.1 : dropping column x29
# cv <  0.1 : dropping column x30
# cv <  0.1 : dropping column x31
# cv <  0.1 : dropping column x32
# cv <  0.1 : dropping column x33
# cv <  0.1 : dropping column x34
# cv <  0.1 : dropping column x36
# cv <  0.1 : dropping column x37
# cv <  0.1 : dropping column x38
# cv <  0.1 : dropping column x40
# cv <  0.1 : dropping column x41
# cv <  0.1 : dropping column x42
# cv <  0.1 : dropping column x43
# cv <  0.1 : dropping column x44
# cv <  0.1 : dropping column x45
# cv <  0.1 : dropping column x46
# cv <  0.1 : dropping column x48
# cv <  0.1 : dropping column x49
# cv <  0.1 : dropping column x50
# cv <  0.1 : dropping column x51
# cv <  0.1 : dropping column x52
# cv <  0.1 : dropping column x53
# cv <  0.1 : dropping column x54
# cv <  0.1 : dropping column x55
# cv <  0.1 : dropping column x56
# cv <  0.1 : dropping column x58
# cv <  0.1 : dropping column x60
# cv <  0.1 : dropping column x61
# cv <  0.1 : dropping column x63
# cv <  0.1 : dropping column x64
# cv <  0.1 : dropping column x65
# cv <  0.1 : dropping column x68
# cv <  0.1 : dropping column x70
# cv <  0.1 : dropping column x71
# cv <  0.1 : dropping column x72
# cv <  0.1 : dropping column x73
# cv <  0.1 : dropping column x74
# cv <  0.1 : dropping column x76
# cv <  0.1 : dropping column x77
# cv <  0.1 : dropping column x78
# cv <  0.1 : dropping column x79
# cv <  0.1 : dropping column x82
# cv <  0.1 : dropping column x83
# cv <  0.1 : dropping column x84
# cv <  0.1 : dropping column x86
# cv <  0.1 : dropping column x87
# cv <  0.1 : dropping column x88
# cv <  0.1 : dropping column x89
# cv <  0.1 : dropping column x93
# cv <  0.1 : dropping column x94
# cv <  0.1 : dropping column x95
# cv <  0.1 : dropping column x96
# cv <  0.1 : dropping column x97
# cv <  0.1 : dropping column x98
# cv <  0.1 : dropping column x99
# cv <  0.1 : dropping column x100
# cv <  0.1 : dropping column x101
# cv <  0.1 : dropping column x103
# cv <  0.1 : dropping column x105
# cv <  0.1 : dropping column x106
# cv <  0.1 : dropping column x107
# cv <  0.1 : dropping column x108
# cv <  0.1 : dropping column x110
# cv <  0.1 : dropping column x112
# cv <  0.1 : dropping column x113
# cv <  0.1 : dropping column x114
# cv <  0.1 : dropping column x117
# cv <  0.1 : dropping column x119
# cv <  0.1 : dropping column x120
# cv <  0.1 : dropping column x122
# cv <  0.1 : dropping column x123
# cv <  0.1 : dropping column x125
# cv <  0.1 : dropping column x128
# cv <  0.1 : dropping column x131
# cv <  0.1 : dropping column x132
# cv <  0.1 : dropping column x133
# cv <  0.1 : dropping column x134
# cv <  0.1 : dropping column x136
# cv <  0.1 : dropping column x137
# cv <  0.1 : dropping column x139
# cv <  0.1 : dropping column x142
# cv <  0.1 : dropping column x143
# cv <  0.1 : dropping column x144
# cv <  0.1 : dropping column x145
# cv <  0.1 : dropping column x146
# cv <  0.1 : dropping column x147
# cv <  0.1 : dropping column x148
# cv <  0.1 : dropping column x150
# cv <  0.1 : dropping column x151
# cv <  0.1 : dropping column x152
# cv <  0.1 : dropping column x153
# cv <  0.1 : dropping column x155
# cv <  0.1 : dropping column x156
# cv <  0.1 : dropping column x157
# cv <  0.1 : dropping column x158
# cv <  0.1 : dropping column x159
# cv <  0.1 : dropping column x160
# cv <  0.1 : dropping column x161
# cv <  0.1 : dropping column x162
# cv <  0.1 : dropping column x163
# cv <  0.1 : dropping column x164
# cv <  0.1 : dropping column x165
# cv <  0.1 : dropping column x166
# cv <  0.1 : dropping column x167
# cv <  0.1 : dropping column x168
# cv <  0.1 : dropping column x172
# cv <  0.1 : dropping column x174
# cv <  0.1 : dropping column x176
# cv <  0.1 : dropping column x178
# cv <  0.1 : dropping column x179
# cv <  0.1 : dropping column x181
# cv <  0.1 : dropping column x182
# cv <  0.1 : dropping column x183
# cv <  0.1 : dropping column x185
# cv <  0.1 : dropping column x186
# cv <  0.1 : dropping column x188
# cv <  0.1 : dropping column x189
# mean = 0: dropping column x193
# cv <  0.1 : dropping column x195
# cv <  0.1 : dropping column x196
# cv <  0.1 : dropping column x197
# cv <  0.1 : dropping column x201
# cv <  0.1 : dropping column x202
# cv <  0.1 : dropping column x203
# cv <  0.1 : dropping column x204
# cv <  0.1 : dropping column x205
# cv <  0.1 : dropping column x206
# cv <  0.1 : dropping column x208
# cv <  0.1 : dropping column x209
# cv <  0.1 : dropping column x211
# cv <  0.1 : dropping column x212
# cv <  0.1 : dropping column x213
# cv <  0.1 : dropping column x214
# cv <  0.1 : dropping column x215
# cv <  0.1 : dropping column x216
# cv <  0.1 : dropping column x217
# cv <  0.1 : dropping column x218
# cv <  0.1 : dropping column x219
# cv <  0.1 : dropping column x220
# cv <  0.1 : dropping column x221
# cv <  0.1 : dropping column x222
# cv <  0.1 : dropping column x224
# cv <  0.1 : dropping column x225
# cv <  0.1 : dropping column x226
# cv <  0.1 : dropping column x228
# cv <  0.1 : dropping column x229
# cv <  0.1 : dropping column x230
# cv <  0.1 : dropping column x231
# cv <  0.1 : dropping column x232
# cv <  0.1 : dropping column x234
# cv <  0.1 : dropping column x235
# cv <  0.1 : dropping column x236
# cv <  0.1 : dropping column x237
# cv <  0.1 : dropping column x238
# cv <  0.1 : dropping column x239
# cv <  0.1 : dropping column x242
# cv <  0.1 : dropping column x243
# cv <  0.1 : dropping column x244
# cv <  0.1 : dropping column x245
# cv <  0.1 : dropping column x246
# cv <  0.1 : dropping column x249
# cv <  0.1 : dropping column x250
# cv <  0.1 : dropping column x252
# cv <  0.1 : dropping column x253
# cv <  0.1 : dropping column x256
# cv <  0.1 : dropping column x257
# cv <  0.1 : dropping column x258
# cv <  0.1 : dropping column x259
# cv <  0.1 : dropping column x260
# cv <  0.1 : dropping column x261
# cv <  0.1 : dropping column x263
# cv <  0.1 : dropping column x264
# cv <  0.1 : dropping column x266
# cv <  0.1 : dropping column x267
# cv <  0.1 : dropping column x268
# cv <  0.1 : dropping column x269
# cv <  0.1 : dropping column x270
# cv <  0.1 : dropping column x271
# cv <  0.1 : dropping column x272
# cv <  0.1 : dropping column x276
# cv <  0.1 : dropping column x277
# cv <  0.1 : dropping column x278
# cv <  0.1 : dropping column x279
# cv <  0.1 : dropping column x280
# cv <  0.1 : dropping column x281
# cv <  0.1 : dropping column x283
# cv <  0.1 : dropping column x284
# cv <  0.1 : dropping column x285
# cv <  0.1 : dropping column x286
# cv <  0.1 : dropping column x287
# cv <  0.1 : dropping column x288
# cv <  0.1 : dropping column x290
# cv <  0.1 : dropping column x292
# cv <  0.1 : dropping column x293
# cv <  0.1 : dropping column x294
# cv <  0.1 : dropping column x295
# mean = 0: dropping column x297
# cv <  0.1 : dropping column x298
# cv <  0.1 : dropping column x299
# cv <  0.1 : dropping column x300
# cv <  0.1 : dropping column x301
# cv <  0.1 : dropping column x303
# cv <  0.1 : dropping column x304
# cv <  0.1 : dropping column x305
# cv <  0.1 : dropping column x306
# cv <  0.1 : dropping column x307
# cv <  0.1 : dropping column x308
# cv <  0.1 : dropping column x309
# cv <  0.1 : dropping column x310
# cv <  0.1 : dropping column x311
# cv <  0.1 : dropping column x312
# cv <  0.1 : dropping column x313
# cv <  0.1 : dropping column x315
# cv <  0.1 : dropping column x316
# cv <  0.1 : dropping column x317
# cv <  0.1 : dropping column x319
# cv <  0.1 : dropping column x320
# cv <  0.1 : dropping column x321
# cv <  0.1 : dropping column x322
# cv <  0.1 : dropping column x324
# cv <  0.1 : dropping column x325
# cv <  0.1 : dropping column x326
# cv <  0.1 : dropping column x327
# cv <  0.1 : dropping column x329
# cv <  0.1 : dropping column x330
# cv <  0.1 : dropping column x331
# cv <  0.1 : dropping column x332
# cv <  0.1 : dropping column x335
# cv <  0.1 : dropping column x336
# cv <  0.1 : dropping column x337
# cv <  0.1 : dropping column x338
# mean = 0: dropping column x339
# cv <  0.1 : dropping column x341
# cv <  0.1 : dropping column x342
# cv <  0.1 : dropping column x345
# cv <  0.1 : dropping column x346
# cv <  0.1 : dropping column x347
# cv <  0.1 : dropping column x348
# cv <  0.1 : dropping column x350
# cv <  0.1 : dropping column x352
# cv <  0.1 : dropping column x355
# cv <  0.1 : dropping column x357
# cv <  0.1 : dropping column x358
# cv <  0.1 : dropping column x359
# cv <  0.1 : dropping column x360
# cv <  0.1 : dropping column x361
# cv <  0.1 : dropping column x362
# cv <  0.1 : dropping column x363
# cv <  0.1 : dropping column x364
# cv <  0.1 : dropping column x365
# cv <  0.1 : dropping column x366
# cv <  0.1 : dropping column x367
# cv <  0.1 : dropping column x368
# cv <  0.1 : dropping column x369
# cv <  0.1 : dropping column x372
# cv <  0.1 : dropping column x373
# cv <  0.1 : dropping column x374
# cv <  0.1 : dropping column x377
# cv <  0.1 : dropping column x378
# cv <  0.1 : dropping column x379
# cv <  0.1 : dropping column x380
# cv <  0.1 : dropping column x382
# cv <  0.1 : dropping column x383
# cv <  0.1 : dropping column x384
# cv <  0.1 : dropping column x385
# cv <  0.1 : dropping column x386
# cv <  0.1 : dropping column x387
# cv <  0.1 : dropping column x388
# cv <  0.1 : dropping column x389
# cv <  0.1 : dropping column x390
# cv <  0.1 : dropping column x391
# cv <  0.1 : dropping column x392
# cv <  0.1 : dropping column x393
# cv <  0.1 : dropping column x394
# cv <  0.1 : dropping column x395
# cv <  0.1 : dropping column x397
# cv <  0.1 : dropping column x398
# cv <  0.1 : dropping column x399
# cv <  0.1 : dropping column x400
# cv <  0.1 : dropping column x401
# cv <  0.1 : dropping column x402
# cv <  0.1 : dropping column x404
# cv <  0.1 : dropping column x405
# cv <  0.1 : dropping column x407
# cv <  0.1 : dropping column x409
# cv <  0.1 : dropping column x410
# cv <  0.1 : dropping column x412
# cv <  0.1 : dropping column x413
# cv <  0.1 : dropping column x414
# cv <  0.1 : dropping column x415
# cv <  0.1 : dropping column x417
# cv <  0.1 : dropping column x418
# cv <  0.1 : dropping column x419
# cv <  0.1 : dropping column x420
# cv <  0.1 : dropping column x421
# cv <  0.1 : dropping column x422
# cv <  0.1 : dropping column x423
# cv <  0.1 : dropping column x424
# cv <  0.1 : dropping column x426
# cv <  0.1 : dropping column x428
# cv <  0.1 : dropping column x429
# cv <  0.1 : dropping column x430
# cv <  0.1 : dropping column x431
# cv <  0.1 : dropping column x433
# cv <  0.1 : dropping column x434
# cv <  0.1 : dropping column x435
# cv <  0.1 : dropping column x436
# cv <  0.1 : dropping column x439
# cv <  0.1 : dropping column x440
# cv <  0.1 : dropping column x441
# cv <  0.1 : dropping column x442
# cv <  0.1 : dropping column x443
# cv <  0.1 : dropping column x444
# cv <  0.1 : dropping column x445
# cv <  0.1 : dropping column x446
# cv <  0.1 : dropping column x447
# cv <  0.1 : dropping column x448
# cv <  0.1 : dropping column x449
# cv <  0.1 : dropping column x450
# cv <  0.1 : dropping column x451
# cv <  0.1 : dropping column x452
# cv <  0.1 : dropping column x454
# cv <  0.1 : dropping column x455
# cv <  0.1 : dropping column x456
# cv <  0.1 : dropping column x459
# cv <  0.1 : dropping column x460
# cv <  0.1 : dropping column x463
# cv <  0.1 : dropping column x464
# cv <  0.1 : dropping column x465
# cv <  0.1 : dropping column x466
# cv <  0.1 : dropping column x468
# cv <  0.1 : dropping column x469
# cv <  0.1 : dropping column x471
# cv <  0.1 : dropping column x472
# cv <  0.1 : dropping column x475
# cv <  0.1 : dropping column x479
# cv <  0.1 : dropping column x480
# cv <  0.1 : dropping column x481
# cv <  0.1 : dropping column x483
# cv <  0.1 : dropping column x484
# cv <  0.1 : dropping column x489
# cv <  0.1 : dropping column x491
# cv <  0.1 : dropping column x492
# cv <  0.1 : dropping column x493
# cv <  0.1 : dropping column x494
# cv <  0.1 : dropping column x495
# cv <  0.1 : dropping column x497
# cv <  0.1 : dropping column x499
# cv <  0.1 : dropping column x500
# cv <  0.1 : dropping column x501
# cv <  0.1 : dropping column x502
# cv <  0.1 : dropping column x503
# cv <  0.1 : dropping column x504
# cv <  0.1 : dropping column x505
# cv <  0.1 : dropping column x506
# cv <  0.1 : dropping column x509
# cv <  0.1 : dropping column x510
# cv <  0.1 : dropping column x511
# cv <  0.1 : dropping column x512
# cv <  0.1 : dropping column x513
# cv <  0.1 : dropping column x514
# cv <  0.1 : dropping column x515
# cv <  0.1 : dropping column x517
# cv <  0.1 : dropping column x518
# cv <  0.1 : dropping column x519
# cv <  0.1 : dropping column x521
# cv <  0.1 : dropping column x524
# cv <  0.1 : dropping column x526
# cv <  0.1 : dropping column x527
# cv <  0.1 : dropping column x528
# cv <  0.1 : dropping column x529
# cv <  0.1 : dropping column x530
# cv <  0.1 : dropping column x531
# cv <  0.1 : dropping column x532
# cv <  0.1 : dropping column x535
# cv <  0.1 : dropping column x539
# cv <  0.1 : dropping column x541
# cv <  0.1 : dropping column x542
# cv <  0.1 : dropping column x544
# cv <  0.1 : dropping column x547
# cv <  0.1 : dropping column x548
# cv <  0.1 : dropping column x549
# cv <  0.1 : dropping column x550
# cv <  0.1 : dropping column x551
# cv <  0.1 : dropping column x552
# cv <  0.1 : dropping column x553
# cv <  0.1 : dropping column x554
# cv <  0.1 : dropping column x555
# cv <  0.1 : dropping column x556
# cv <  0.1 : dropping column x558
# cv <  0.1 : dropping column x562
# cv <  0.1 : dropping column x563
# cv <  0.1 : dropping column x564
# cv <  0.1 : dropping column x565
# cv <  0.1 : dropping column x567
# cv <  0.1 : dropping column x569
# cv <  0.1 : dropping column x570
# cv <  0.1 : dropping column x571
# cv <  0.1 : dropping column x572
# cv <  0.1 : dropping column x573
# cv <  0.1 : dropping column x574
# cv <  0.1 : dropping column x576
# cv <  0.1 : dropping column x580
# cv <  0.1 : dropping column x582
# cv <  0.1 : dropping column x583
# cv <  0.1 : dropping column x584
# cv <  0.1 : dropping column x585
# cv <  0.1 : dropping column x586
# cv <  0.1 : dropping column x587
# cv <  0.1 : dropping column x588
# cv <  0.1 : dropping column x589
# cv <  0.1 : dropping column x590
# cv <  0.1 : dropping column x592
# cv <  0.1 : dropping column x593
# cv <  0.1 : dropping column x595
# cv <  0.1 : dropping column x596
# cv <  0.1 : dropping column x597
# cv <  0.1 : dropping column x598
# cv <  0.1 : dropping column x599
# cv <  0.1 : dropping column x600
# cv <  0.1 : dropping column x601
# cv <  0.1 : dropping column x602
# cv <  0.1 : dropping column x603
# cv <  0.1 : dropping column x604
# cv <  0.1 : dropping column x605
# cv <  0.1 : dropping column x606
# cv <  0.1 : dropping column x607
# cv <  0.1 : dropping column x609
# cv <  0.1 : dropping column x610
# cv <  0.1 : dropping column x611
# cv <  0.1 : dropping column x612
# cv <  0.1 : dropping column x613
# cv <  0.1 : dropping column x614
# cv <  0.1 : dropping column x616
# cv <  0.1 : dropping column x617
# cv <  0.1 : dropping column x618
# cv <  0.1 : dropping column x619
# cv <  0.1 : dropping column x620
# cv <  0.1 : dropping column x622
# cv <  0.1 : dropping column x623
# cv <  0.1 : dropping column x624
# cv <  0.1 : dropping column x625
# cv <  0.1 : dropping column x626
# cv <  0.1 : dropping column x627
# cv <  0.1 : dropping column x628
# mean = 0: dropping column x629
# cv <  0.1 : dropping column x630
# cv <  0.1 : dropping column x631
# cv <  0.1 : dropping column x632
# cv <  0.1 : dropping column x633
# cv <  0.1 : dropping column x634
# cv <  0.1 : dropping column x636
# cv <  0.1 : dropping column x638
# cv <  0.1 : dropping column x639
# cv <  0.1 : dropping column x640
# cv <  0.1 : dropping column x641
# cv <  0.1 : dropping column x645
# cv <  0.1 : dropping column x647
# cv <  0.1 : dropping column x649
# cv <  0.1 : dropping column x650
# cv <  0.1 : dropping column x651
# cv <  0.1 : dropping column x652
# cv <  0.1 : dropping column x653
# cv <  0.1 : dropping column x656
# cv <  0.1 : dropping column x658
# cv <  0.1 : dropping column x659
# cv <  0.1 : dropping column x660
# cv <  0.1 : dropping column x663
# cv <  0.1 : dropping column x664
# cv <  0.1 : dropping column x665
# cv <  0.1 : dropping column x666
# cv <  0.1 : dropping column x667
# cv <  0.1 : dropping column x668
# cv <  0.1 : dropping column x669
# cv <  0.1 : dropping column x670
# cv <  0.1 : dropping column x671
# cv <  0.1 : dropping column x673
# cv <  0.1 : dropping column x674
# cv <  0.1 : dropping column x676
# cv <  0.1 : dropping column x677
# cv <  0.1 : dropping column x678
# cv <  0.1 : dropping column x679
# cv <  0.1 : dropping column x681
# cv <  0.1 : dropping column x682
# cv <  0.1 : dropping column x684
# cv <  0.1 : dropping column x685
# cv <  0.1 : dropping column x694
# cv <  0.1 : dropping column x695
# cv <  0.1 : dropping column x697
# cv <  0.1 : dropping column x698
# cv <  0.1 : dropping column x699
# cv <  0.1 : dropping column x700
# cv <  0.1 : dropping column x701
# cv <  0.1 : dropping column x702
# cv <  0.1 : dropping column x703
# cv <  0.1 : dropping column x704
# cv <  0.1 : dropping column x705
# cv <  0.1 : dropping column x706
# cv <  0.1 : dropping column x707
# cv <  0.1 : dropping column x708
# cv <  0.1 : dropping column x709
# cv <  0.1 : dropping column x710
# cv <  0.1 : dropping column x711
# cv <  0.1 : dropping column x712
# cv <  0.1 : dropping column x714
# cv <  0.1 : dropping column x716
# cv <  0.1 : dropping column x718
# cv <  0.1 : dropping column x719
# cv <  0.1 : dropping column x720
# cv <  0.1 : dropping column x721
# cv <  0.1 : dropping column x722
# cv <  0.1 : dropping column x724
# cv <  0.1 : dropping column x725
# cv <  0.1 : dropping column x727
# cv <  0.1 : dropping column x729
# cv <  0.1 : dropping column x730
# cv <  0.1 : dropping column x731
# cv <  0.1 : dropping column x732
# cv <  0.1 : dropping column x734
# cv <  0.1 : dropping column x735
# cv <  0.1 : dropping column x737
# cv <  0.1 : dropping column x740
# cv <  0.1 : dropping column x741
# cv <  0.1 : dropping column x742
# cv <  0.1 : dropping column x743
# cv <  0.1 : dropping column x744
# cv <  0.1 : dropping column x746
# cv <  0.1 : dropping column x747
# cv <  0.1 : dropping column x748
# cv <  0.1 : dropping column x750
# cv <  0.1 : dropping column x751
# cv <  0.1 : dropping column x752
# cv <  0.1 : dropping column x753
# cv <  0.1 : dropping column x754
# cv <  0.1 : dropping column x755
# cv <  0.1 : dropping column x756
# cv <  0.1 : dropping column x758
# cv <  0.1 : dropping column x759
# cv <  0.1 : dropping column x762
# cv <  0.1 : dropping column x763
# cv <  0.1 : dropping column x765
# cv <  0.1 : dropping column x767
# cv <  0.1 : dropping column x768
# cv <  0.1 : dropping column x769
# cv <  0.1 : dropping column x770
# cv <  0.1 : dropping column x771
# cv <  0.1 : dropping column x772
# cv <  0.1 : dropping column x775
# cv <  0.1 : dropping column x777
# cv <  0.1 : dropping column x778
# cv <  0.1 : dropping column x781
# cv <  0.1 : dropping column x782
# cv <  0.1 : dropping column x786
# cv <  0.1 : dropping column x787
# cv <  0.1 : dropping column x788
# cv <  0.1 : dropping column x789
# cv <  0.1 : dropping column x790
# cv <  0.1 : dropping column x792
# cv <  0.1 : dropping column x793
# cv <  0.1 : dropping column x794
# cv <  0.1 : dropping column x795
# cv <  0.1 : dropping column x796
# cv <  0.1 : dropping column x799
# cv <  0.1 : dropping column x800
# cv <  0.1 : dropping column x801
# cv <  0.1 : dropping column x802
# cv <  0.1 : dropping column x804
# cv <  0.1 : dropping column x805
# cv <  0.1 : dropping column x806
# cv <  0.1 : dropping column x807
# cv <  0.1 : dropping column x808
# cv <  0.1 : dropping column x809
# cv <  0.1 : dropping column x810
# cv <  0.1 : dropping column x811
# cv <  0.1 : dropping column x812
# cv <  0.1 : dropping column x814
# cv <  0.1 : dropping column x815
# cv <  0.1 : dropping column x816
# cv <  0.1 : dropping column x817
# cv <  0.1 : dropping column x818
# cv <  0.1 : dropping column x819
# cv <  0.1 : dropping column x820
# cv <  0.1 : dropping column x821
# cv <  0.1 : dropping column x822
# cv <  0.1 : dropping column x823
# cv <  0.1 : dropping column x825
# cv <  0.1 : dropping column x826
# cv <  0.1 : dropping column x829
# cv <  0.1 : dropping column x830
# cv <  0.1 : dropping column x831
# 612 833

# %%
#check that indeed the column contains only zeros
df_x["x629"]
# Out:
# 0       0.0
# 1       0.0
# 2       NaN
# 3       0.0
# 4       0.0
#        ...
# 1207    0.0
# 1208    0.0
# 1209    0.0
# 1210    0.0
# 1211    0.0
# Name: x629, Length: 1212, dtype: float64

# %%
#drop the columns with mean = 0 and cv < cv_min
df_x.drop(dropped_cols_mean,axis=1,inplace=True)
df_x.drop(dropped_cols_cv,axis=1,inplace=True)

# %%
df_x.head(10)
# Out:
#     id            x7            x8           x10           x12          x22  \
# 0  0.0           NaN  1.144294e+06  38042.008654  67475.900839  2538.045240
# 1  1.0   8127.016078  1.099166e+06  50949.420639  93179.779900  2033.004526
# 2  2.0  10738.092422  1.027863e+06  47259.321206  69377.195188  2138.054129
# 3  3.0  13524.096973  1.168144e+06  53507.052907  85953.175663  2618.086812
# 4  4.0  12894.065081  1.063199e+06  52954.782341  90224.274392  2462.022541
# 5  5.0   9730.044411  9.758330e+05  50111.875986  84175.428187  3203.073464
# 6  6.0  12080.006126  9.537706e+05  53753.829322  89232.030861  3484.020593
# 7  7.0   9340.060849  1.100990e+06  40234.962455  86229.259583  2503.029842
# 8  8.0   9189.051680  1.025698e+06  37094.253173  65807.541570  2054.006059
# 9  9.0   8964.010556  8.698899e+05  41701.170161  75222.233560  2340.018293
#
#            x25           x28          x35           x39  ...         x784  \
# 0  1530.001316   9902.072478  5555.414472  14709.216512  ...    42.134108
# 1  2119.097861  10414.075263  4784.223551  12616.740072  ...    55.581405
# 2  1926.041068  12163.033117  4317.864410  13070.565105  ...    84.682359
# 3  2402.018255  17640.001069  5728.033993  20564.616684  ...    51.056049
# 4  1784.063399  16711.053379  5535.494157  22497.004497  ...  1366.019674
# 5  1924.038355  12176.092127  5020.633028  15646.273865  ...    99.559771
# 6  1972.073077  12446.030417  5600.797419  17479.522029  ...   126.236729
# 7          NaN  12715.055500  3702.317776  15903.209665  ...    88.578110
# 8          NaN   9172.083930  5197.376890  13871.678555  ...   111.577908
# 9  2087.089335  13709.072007  5000.376747  17961.873481  ...    46.321222
#
#           x785          x791          x797         x798           x803  \
# 0  2457.075229   9046.047584  11230.077183  1132.878438  309702.424398
# 1  2295.387016  10628.015226  10487.069231   695.406075  557053.464687
# 2  1471.906345  12841.021669  11122.087230   862.889649  396496.091177
# 3   884.023158  15391.018521  13292.071797          NaN  496861.936593
# 4  1832.255623  12886.012745           NaN  1111.883447  457342.316287
# 5  2217.590316  12052.009324  12847.031362   955.089060  418758.207096
# 6  2454.560977  13141.006251           NaN  1111.043429  498465.717810
# 7  3853.229723  11011.043392  12726.010329  1036.244838  469082.877668
# 8   904.278059   9454.038010  11482.040352  1086.284989  355136.837233
# 9   963.329206   9637.007479  11083.082867   913.934839  410207.595206
#
#           x813          x824         x827       x828
# 0  1857.070822  12176.073427  1220.065443   8.566724
# 1  1818.087105  10493.095660   917.094909  10.231822
# 2  1895.067520  10959.516944   637.027802  10.705461
# 3  2390.011297  16845.309819  1114.069590  10.321063
# 4  2764.063614  18348.460040  1230.088215  10.250096
# 5  2487.085145  12838.791399  1230.071653  11.034434
# 6  2461.027724  14383.974419  1076.013807  10.228285
# 7  1724.092092  13160.616216  1003.027110  10.383666
# 8  1324.009657  11486.628404   946.050997   9.122541
# 9  1289.082888  14801.991962   976.059612   9.992425
#
# [10 rows x 221 columns]

# %%
#replace each column's nan with the mean value
for column in df_x:
    if df_x[column].isnull().values.any():
        mean = df_x[column].astype("float").mean()
        df_x[column].replace(np.nan, mean, inplace=True)
df_x.head(10)
# Out:
#     id            x7            x8           x10           x12          x22  \
# 0  0.0  10389.657239  1.144294e+06  38042.008654  67475.900839  2538.045240
# 1  1.0   8127.016078  1.099166e+06  50949.420639  93179.779900  2033.004526
# 2  2.0  10738.092422  1.027863e+06  47259.321206  69377.195188  2138.054129
# 3  3.0  13524.096973  1.168144e+06  53507.052907  85953.175663  2618.086812
# 4  4.0  12894.065081  1.063199e+06  52954.782341  90224.274392  2462.022541
# 5  5.0   9730.044411  9.758330e+05  50111.875986  84175.428187  3203.073464
# 6  6.0  12080.006126  9.537706e+05  53753.829322  89232.030861  3484.020593
# 7  7.0   9340.060849  1.100990e+06  40234.962455  86229.259583  2503.029842
# 8  8.0   9189.051680  1.025698e+06  37094.253173  65807.541570  2054.006059
# 9  9.0   8964.010556  8.698899e+05  41701.170161  75222.233560  2340.018293
#
#            x25           x28          x35           x39  ...         x784  \
# 0  1530.001316   9902.072478  5555.414472  14709.216512  ...    42.134108
# 1  2119.097861  10414.075263  4784.223551  12616.740072  ...    55.581405
# 2  1926.041068  12163.033117  4317.864410  13070.565105  ...    84.682359
# 3  2402.018255  17640.001069  5728.033993  20564.616684  ...    51.056049
# 4  1784.063399  16711.053379  5535.494157  22497.004497  ...  1366.019674
# 5  1924.038355  12176.092127  5020.633028  15646.273865  ...    99.559771
# 6  1972.073077  12446.030417  5600.797419  17479.522029  ...   126.236729
# 7  1902.756900  12715.055500  3702.317776  15903.209665  ...    88.578110
# 8  1902.756900   9172.083930  5197.376890  13871.678555  ...   111.577908
# 9  2087.089335  13709.072007  5000.376747  17961.873481  ...    46.321222
#
#           x785          x791          x797         x798           x803  \
# 0  2457.075229   9046.047584  11230.077183  1132.878438  309702.424398
# 1  2295.387016  10628.015226  10487.069231   695.406075  557053.464687
# 2  1471.906345  12841.021669  11122.087230   862.889649  396496.091177
# 3   884.023158  15391.018521  13292.071797   998.532614  496861.936593
# 4  1832.255623  12886.012745  12054.454596  1111.883447  457342.316287
# 5  2217.590316  12052.009324  12847.031362   955.089060  418758.207096
# 6  2454.560977  13141.006251  12054.454596  1111.043429  498465.717810
# 7  3853.229723  11011.043392  12726.010329  1036.244838  469082.877668
# 8   904.278059   9454.038010  11482.040352  1086.284989  355136.837233
# 9   963.329206   9637.007479  11083.082867   913.934839  410207.595206
#
#           x813          x824         x827       x828
# 0  1857.070822  12176.073427  1220.065443   8.566724
# 1  1818.087105  10493.095660   917.094909  10.231822
# 2  1895.067520  10959.516944   637.027802  10.705461
# 3  2390.011297  16845.309819  1114.069590  10.321063
# 4  2764.063614  18348.460040  1230.088215  10.250096
# 5  2487.085145  12838.791399  1230.071653  11.034434
# 6  2461.027724  14383.974419  1076.013807  10.228285
# 7  1724.092092  13160.616216  1003.027110  10.383666
# 8  1324.009657  11486.628404   946.050997   9.122541
# 9  1289.082888  14801.991962   976.059612   9.992425
#
# [10 rows x 221 columns]

# %%
df = pd.concat([df_y,df_x],axis=1)
df.drop(["id"],axis=1,inplace=True)
df.describe()
# Out:
#                  y            x7            x8           x10            x12  \
# count  1212.000000   1212.000000  1.212000e+03   1212.000000    1212.000000
# mean     69.665842  10389.657239  9.998422e+05  45052.406618   79202.109585
# std       9.831347   1596.674554  9.810785e+04   5480.481790    9761.383365
# min      42.000000   3644.074892  6.095730e+05  12216.799005   33020.798595
# 25%      64.000000   9409.300050  9.430492e+05  41731.082424   73080.771121
# 50%      70.000000  10389.657239  9.998422e+05  45052.406618   79202.109585
# 75%      76.000000  11212.573544  1.060764e+06  47924.795297   84461.106562
# max      97.000000  17347.531573  1.284804e+06  62920.672170  119728.191397
#
#                x22          x25           x28          x35           x39  ...  \
# count  1212.000000  1212.000000   1212.000000  1212.000000   1212.000000  ...
# mean   2420.918931  1902.756900  12894.643842  4957.471234  16399.818073  ...
# std     458.212598   290.750226   2163.540608   773.092717   3033.883278  ...
# min     883.142264   949.810092   3790.098721  2589.298944   2931.644420  ...
# 25%    2124.070509  1718.056577  11618.007821  4501.533957  14698.805272  ...
# 50%    2420.000228  1902.756900  12892.079971  4957.471234  16399.818073  ...
# 75%    2663.813116  2084.325449  14138.810380  5337.110198  17960.676805  ...
# max    4321.037607  2905.888553  22147.762396  9812.825234  30245.453241  ...
#
#               x784         x785          x791          x797         x798  \
# count  1212.000000  1212.000000   1212.000000   1212.000000  1212.000000
# mean    104.817993  1490.895126  11635.853966  12054.454596   998.532614
# std      86.997974   679.610725   1815.996845   1757.202472    97.084359
# min       0.000000  -782.066388   4496.909991   5021.605896   579.255832
# 25%      70.065202  1019.545721  10509.079806  11006.512862   941.853113
# 50%      98.689156  1447.834219  11635.853966  12054.454596   998.532614
# 75%     122.504442  1829.261636  12745.554198  12997.295486  1056.619445
# max    1616.836295  5028.234155  18900.416596  19039.437934  1338.244886
#
#                 x803         x813          x824         x827         x828
# count    1212.000000  1212.000000   1212.000000  1212.000000  1212.000000
# mean   429980.004506  1841.034903  13492.600186  1066.141107    10.008269
# std     66318.346214   362.080206   2398.299115   216.755988     0.977271
# min    155590.944477   873.012033   2536.030655   496.007706     6.466963
# 25%    389810.483312  1591.059620  12164.233176   914.763005     9.384658
# 50%    429980.004506  1841.034903  13492.600186  1066.141107    10.008269
# 75%    464024.745889  2046.313497  14700.041808  1194.283142    10.603448
# max    681846.301656  3133.053640  24815.260375  2122.032859    13.163113
#
# [8 rows x 221 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
p = df.corr()
plt.matshow(p)
plt.show()

# %%
p
type(p)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Ideas
# 1. group the features by their pearson correlation coefficient (with respect to y)
#   * 1 positive correlation
#   * 0 no correlation
#   * 1 negative correlation
# 2. check the statistical significance with p value
#   * p-value is $<$ 0.001: we say there is strong evidence that the correlation is significant
#   * the p-value is $<$ 0.05: there is moderate evidence that the correlation is significant
#   * the p-value is $<$ 0.1: there is weak evidence that the correlation is significant
#   * the p-value is $>$ 0.1: there is no evidence that the correlation is significant

# %%
p_y = p[["y"]]
p_y
#p_y.columns(["feature","PCC"])
#p_y.drop(["y"],axis=0,inplace=True)
# Out:
#              y
# y     1.000000
# x7   -0.339417
# x8   -0.056085
# x10  -0.245100
# x12  -0.165326
# ...        ...
# x803 -0.279118
# x813 -0.155065
# x824 -0.336848
# x827 -0.232269
# x828 -0.029373
#
# [221 rows x 1 columns]

# %%
#bin the Pearson correlation coefficients
bins = np.linspace(-1, 1, 7)
group_names = ["neg[1-0.67]", "neg[0.67-0.33]", "neg[0.33-0]", "[0-0.33]", "[0.33-0.67]", "[0.67-1]"]
p_y.loc[:,"y-binned"] = pd.cut(p_y.loc[:,"y"], bins, labels=group_names, include_lowest=True)
p_y[["y","y-binned"]].head(20)
# Out:
#             y        y-binned
# y    1.000000        [0.67-1]
# x7  -0.339417  neg[0.67-0.33]
# x8  -0.056085     neg[0.33-0]
# x10 -0.245100     neg[0.33-0]
# x12 -0.165326     neg[0.33-0]
# x22 -0.143973     neg[0.33-0]
# x25 -0.253763     neg[0.33-0]
# x28 -0.262967     neg[0.33-0]
# x35 -0.274068     neg[0.33-0]
# x39 -0.328600     neg[0.33-0]
# x47 -0.286736     neg[0.33-0]
# x57  0.009225        [0-0.33]
# x59 -0.054209     neg[0.33-0]
# x62  0.134759        [0-0.33]
# x66 -0.212192     neg[0.33-0]
# x67 -0.294227     neg[0.33-0]
# x69 -0.136606     neg[0.33-0]
# x75 -0.237880     neg[0.33-0]
# x80 -0.204760     neg[0.33-0]
# x81 -0.283581     neg[0.33-0]

# %%
#histogram
p_y["y-binned"].value_counts()
# Out:
# neg[0.33-0]       144
# [0-0.33]           45
# neg[0.67-0.33]     23
# [0.33-0.67]         8
# [0.67-1]            1
# neg[1-0.67]         0
# Name: y-binned, dtype: int64

# %%
#features in top category
p_y_033_067 = p_y[p_y["y-binned"]=="[0.33-0.67]"]
p_y_033_067.head(10)
# Out:
#              y     y-binned
# x85   0.426241  [0.33-0.67]
# x170  0.407747  [0.33-0.67]
# x302  0.347802  [0.33-0.67]
# x408  0.403908  [0.33-0.67]
# x457  0.336854  [0.33-0.67]
# x559  0.397339  [0.33-0.67]
# x776  0.401790  [0.33-0.67]
# x785  0.404822  [0.33-0.67]

# %%
#plot some of them
import seaborn as sns
sns.regplot(x="x559", y="y", data=df)
plt.ylim(0,)
# Out:
# (0.0, 109.69055648093412)

# %%
ax = sns.boxplot(x=df["x559"])

# %%
#features in 2nd to top category
#features in top category
p_y_0_033 = p_y[p_y["y-binned"]=="[0-0.33]"]
p_y_0_033.head(20)
# Out:
#              y  y-binned
# x57   0.009225  [0-0.33]
# x62   0.134759  [0-0.33]
# x90   0.002887  [0-0.33]
# x109  0.046520  [0-0.33]
# x111  0.003675  [0-0.33]
# x115  0.046315  [0-0.33]
# x149  0.048532  [0-0.33]
# x190  0.001862  [0-0.33]
# x194  0.047610  [0-0.33]
# x247  0.263453  [0-0.33]
# x248  0.026101  [0-0.33]
# x251  0.075261  [0-0.33]
# x255  0.024038  [0-0.33]
# x262  0.036083  [0-0.33]
# x314  0.001181  [0-0.33]
# x318  0.039099  [0-0.33]
# x333  0.004529  [0-0.33]
# x340  0.009594  [0-0.33]
# x370  0.003243  [0-0.33]
# x376  0.020395  [0-0.33]

# %%
sns.regplot(x="x62", y="y", data=df)
plt.ylim(0,)
# Out:
# (0.0, 99.75)

# %%
ax = sns.boxplot(x=df["x62"])

# %%
#features in bottom category
p_y_n67_033 = p_y[p_y["y-binned"]=="neg[0.67-0.33]"]
p_y_n67_033.head(20)
# Out:
#              y        y-binned
# x7   -0.339417  neg[0.67-0.33]
# x129 -0.407543  neg[0.67-0.33]
# x169 -0.337744  neg[0.67-0.33]
# x180 -0.391423  neg[0.67-0.33]
# x184 -0.482062  neg[0.67-0.33]
# x192 -0.346801  neg[0.67-0.33]
# x198 -0.336974  neg[0.67-0.33]
# x223 -0.394165  neg[0.67-0.33]
# x227 -0.414195  neg[0.67-0.33]
# x289 -0.449960  neg[0.67-0.33]
# x453 -0.337459  neg[0.67-0.33]
# x473 -0.427889  neg[0.67-0.33]
# x485 -0.362508  neg[0.67-0.33]
# x488 -0.350544  neg[0.67-0.33]
# x496 -0.393741  neg[0.67-0.33]
# x537 -0.487386  neg[0.67-0.33]
# x635 -0.338371  neg[0.67-0.33]
# x661 -0.333679  neg[0.67-0.33]
# x672 -0.394556  neg[0.67-0.33]
# x686 -0.334090  neg[0.67-0.33]

# %%
sns.regplot(x="x537", y="y", data=df)
plt.ylim(0,)
# Out:
# (0.0, 99.75)

# %%
ax = sns.boxplot(x=df["x537"])

# %%
#features in 2nd bottom category
p_y_n033_0 = p_y[p_y["y-binned"]=="neg[0.33-0]"]
p_y_n033_0.head(20)
# Out:
#              y     y-binned
# x8   -0.056085  neg[0.33-0]
# x10  -0.245100  neg[0.33-0]
# x12  -0.165326  neg[0.33-0]
# x22  -0.143973  neg[0.33-0]
# x25  -0.253763  neg[0.33-0]
# x28  -0.262967  neg[0.33-0]
# x35  -0.274068  neg[0.33-0]
# x39  -0.328600  neg[0.33-0]
# x47  -0.286736  neg[0.33-0]
# x59  -0.054209  neg[0.33-0]
# x66  -0.212192  neg[0.33-0]
# x67  -0.294227  neg[0.33-0]
# x69  -0.136606  neg[0.33-0]
# x75  -0.237880  neg[0.33-0]
# x80  -0.204760  neg[0.33-0]
# x81  -0.283581  neg[0.33-0]
# x91  -0.116306  neg[0.33-0]
# x92  -0.041236  neg[0.33-0]
# x102 -0.234256  neg[0.33-0]
# x104 -0.023279  neg[0.33-0]

# %%
sns.regplot(x="x66", y="y", data=df)
plt.ylim(0,)
# Out:
# (0.0, 99.75)

# %%
ax = sns.boxplot(x=df["x537"])

# %% [markdown]
# ### Reduced correlation matrix for significant variables
# Look at the correlation between variables in the top and bottom intervals

# %%
p_y_n67_033.index
# Out:
# Index(['x7', 'x129', 'x169', 'x180', 'x184', 'x192', 'x198', 'x223', 'x227',
#        'x289', 'x453', 'x473', 'x485', 'x488', 'x496', 'x537', 'x635', 'x661',
#        'x672', 'x686', 'x717', 'x726', 'x824'],
#       dtype='object')

# %%
df2 = df[['x7', 'x129', 'x169', 'x180', 'x184', 'x192', 'x198', 'x223', 'x227',
       'x289', 'x453', 'x473', 'x485', 'x488', 'x496', 'x537', 'x635', 'x661',
       'x672', 'x686', 'x717', 'x726', 'x824']]

# %%
p_y_033_067.index
# Out:
# Index(['x85', 'x170', 'x302', 'x408', 'x457', 'x559', 'x776', 'x785'], dtype='object')

# %%
df3 = df[['y','x85', 'x170', 'x302', 'x408', 'x457', 'x559', 'x776', 'x785']]

# %%
df_top = pd.concat([df3,df2],axis=1)
df_top.head(5)
# Out:
#       y           x85         x170        x302          x408         x457  \
# 0  71.0   2827.633110   688.451142   19.668968  15566.987383  2254.394228
# 1  73.0  17622.701107  3848.155273  145.922872  32527.317973  2099.398571
# 2  66.0   2275.991296   641.868780   23.430892  13550.245792  1915.921776
# 3  55.0    991.045547   231.043720    8.005069   4600.089592  1218.039388
# 4  67.0   1592.045883   398.678181   92.880848  12062.854137  2038.497359
#
#            x559         x776         x785            x7  ...          x488  \
# 0  19617.700416   721.529170  2457.075229  10389.657239  ...  23013.846115
# 1  36997.615079  2610.588172  2295.387016   8127.016078  ...  19762.373642
# 2  16302.197848   595.101994  1471.906345  10738.092422  ...  20511.894683
# 3   4752.034757   608.024214   884.023158  13524.096973  ...  32095.653753
# 4  13694.160144   154.266692  1832.255623  12894.065081  ...  35077.923146
#
#          x496         x537        x635         x661         x672  \
# 0  303.410182  3826.945523  586.395086  1855.011162  1640.875752
# 1  325.511739  2988.074601  763.194824  1711.035712  1253.778144
# 2  379.808563  3708.024374  749.793789  1974.013900  1468.097750
# 3  723.099953  4933.028394  718.058402  2184.066394  1853.040723
# 4  427.802291  3733.313477  749.285756  2204.020533  1880.719682
#
#            x686          x717        x726          x824
# 0   7966.073053  16665.272450  324.766557  12176.073427
# 1   6850.048029  16437.776213  420.255007  10493.095660
# 2   7126.070664  25885.334589  332.600344  10959.516944
# 3  11077.093511  27283.626670  804.033376  16845.309819
# 4  12091.078957  31407.830023  420.005439  18348.460040
#
# [5 rows x 32 columns]

# %%
p_top = df_top.corr()
plt.matshow(p_top)
plt.show()

# %%
ax = sns.boxplot(x=df_top["x559"])

# %% [markdown]
# ### Next steps
# ### Automatic Outlier detection
# Try out different algorithms:\
# <https://machinelearningmastery.com/model-based-outlier-detection-and-removal-in-python/>\
# <https://towardsdatascience.com/a-brief-overview-of-outlier-detection-techniques-1e0b2c19e561>
# 1. Isolation Forest
# 2. Others...
#
# ### Automatic Feature Selection
# 1. RFE <https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.RFE.html#sklearn.feature_selection.RFE>
# 2. PCA

# %%
#create df from iso by removing the target
print(df_top.columns)
iso_Y_arr = df_top["y"].to_numpy()
df_iso = df_top.drop(["y"],axis=1)
iso_X_arr = df_iso.to_numpy()
print(iso_X_arr.shape)
#df_iso.head(5)
# Out:
# Index(['y', 'x85', 'x170', 'x302', 'x408', 'x457', 'x559', 'x776', 'x785',
#        'x7', 'x129', 'x169', 'x180', 'x184', 'x192', 'x198', 'x223', 'x227',
#        'x289', 'x453', 'x473', 'x485', 'x488', 'x496', 'x537', 'x635', 'x661',
#        'x672', 'x686', 'x717', 'x726', 'x824'],
#       dtype='object')
# (1212, 31)

# %%
# use Isolation Forest to indentify outliers on the selected features
from sklearn.ensemble import IsolationForest
cont_fl = 0.3
iso = IsolationForest(contamination=cont_fl)
yhat = iso.fit_predict(iso_X_arr)
print(yhat.shape, iso_X_arr.shape)
mask = yhat != -1
iso_X_arr, iso_Y_arr = iso_X_arr[mask, :], iso_Y_arr[mask]
numrows = len(iso_X_arr)    
numcols = len(iso_X_arr[0])
iso_arr = np.random.rand(numrows,numcols+1)
iso_arr[:,0]=iso_Y_arr
iso_arr[:,1:(numcols+1)]=iso_X_arr
print(numrows,numcols)
print(iso_arr.shape)
# Out:
# (1212,) (1212, 31)
# 848 31
# (848, 32)

# %%
# compare against plots before Isolation forest
df_top_iso = pd.DataFrame(data=iso_arr, columns=['y','x85', 'x170', 'x302', 'x408', 'x457', 'x559', 'x776', 'x785',
'x7', 'x129', 'x169', 'x180', 'x184', 'x192', 'x198', 'x223', 'x227',
'x289', 'x453', 'x473', 'x485', 'x488', 'x496', 'x537', 'x635', 'x661',
'x672', 'x686', 'x717', 'x726', 'x824'])
df_top_iso.head()
# Out:
#       y          x85        x170       x302          x408         x457  \
# 0  71.0  2827.633110  688.451142  19.668968  15566.987383  2254.394228
# 1  66.0  2275.991296  641.868780  23.430892  13550.245792  1915.921776
# 2  75.0  4763.303001  524.319394  44.877625  18590.613068  2342.814323
# 3  67.0  1896.982848  400.095180  38.654483  14549.100755  2538.916209
# 4  70.0  1378.048349  226.039859  54.760418   6932.068018  1460.950959
#
#            x559        x776         x785            x7  ...          x488  \
# 0  19617.700416  721.529170  2457.075229  10389.657239  ...  23013.846115
# 1  16302.197848  595.101994  1471.906345  10738.092422  ...  20511.894683
# 2  19033.003625  670.316183  2217.590316   9730.044411  ...  24431.134376
# 3  16191.838669  271.545425  2454.560977  12080.006126  ...  27309.193782
# 4   8859.397921   95.380345   904.278059   9189.051680  ...  21708.504152
#
#          x496         x537        x635         x661         x672         x686  \
# 0  303.410182  3826.945523  586.395086  1855.011162  1640.875752  7966.073053
# 1  379.808563  3708.024374  749.793789  1974.013900  1468.097750  7126.070664
# 2  315.979521  3933.675011  718.181379  1709.048211  1468.097750  8436.011226
# 3  353.793586  3993.930632  850.590967  2006.026488  1492.744094  9437.011010
# 4  382.589403  3328.499376  866.052666  1764.087423  1481.067718  7515.065687
#
#            x717        x726          x824
# 0  16665.272450  324.766557  12176.073427
# 1  25885.334589  332.600344  10959.516944
# 2  21588.783861  312.573918  12838.791399
# 3  18265.053277  370.136870  14383.974419
# 4  20451.335289  399.696421  11486.628404
#
# [5 rows x 32 columns]

# %%
ax = sns.boxplot(x=df_top_iso["x559"])

# %%
ax =sns.regplot(x="x559", y="y", data=df_top_iso)
plt.ylim(0,)
# Out:
# (0.0, 91.3)

# %%
ax = sns.boxplot(x=df_top_iso["x537"])

# %%
sns.regplot(x="x537", y="y", data=df_top_iso)
plt.ylim(0,)
# Out:
# (0.0, 91.3)
